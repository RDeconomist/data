# %% [markdown]
# All I need to do is melt:

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("/Users/finn/Documents/GitHub/data/e4e7/Uncleaned Data/US_Trade.xlsx", sheet_name="Polished")

# %%
df.melt(id_vars=["Year"], var_name="Series", value_name="Value").to_csv("/Users/finn/Documents/GitHub/data/e4e7/US_Trade.csv", index=False)

# %%
df
# Out:
#     Year  Nominal_Balance  Nominal_Goods_Balance  Nominal_Goods_Exports  \
# 0   1960       3508000000             4892000000            19650000000
# 1   1961       4194000000             5571000000            20108000000
# 2   1962       3371000000             4521000000            20781000000
# 3   1963       4210000000             5224000000            22272000000
# 4   1964       6022000000             6801000000            25501000000
# ..   ...              ...                    ...                    ...
# 58  2018    -578594000000          -878749000000          1676913000000
# 59  2019    -559676000000          -857260000000          1655098000000
# 60  2020    -653989000000          -913885000000          1432218000000
# 61  2021    -845047000000         -1090296000000          1761364000000
# 62  2022    -945319000000         -1191029000000          2085847000000
#
#     Nominal_Goods_Imports  Nominal_Services_Balance  Nominal_Services_Exports  \
# ...
